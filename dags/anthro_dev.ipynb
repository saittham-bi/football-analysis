# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import os
import io
import duckdb

# %%
## Load dotenv variables
load_dotenv()

#Initialize duckdb with postgres connector    
cursor = duckdb.connect()
cursor.sql("INSTALL postgres;")
cursor.sql("LOAD postgres;")
cursor.sql(f"""
           ATTACH 'dbname=youthbase user={os.getenv("PG_SPORTANALYTICS_USER")} password={os.getenv("PG_SPORTANALYTICS_PASSWORD")} 
           host={os.getenv("PG_SPORTANALYTICS_HOST")}' AS postgres_db (TYPE POSTGRES);
           """)

# %%
## Get all file_ids from bucket

# Define directory URL and create empty file id list
dir_uri = f'{os.getenv("kd_dns")}3/drive/{os.getenv("kd_id")}/files/4777/files'
headers = {'Authorization': 'Bearer ' + os.getenv("kd_token")}
file_ids = []

# Return results from paginated API request
response = requests.get(dir_uri, headers=headers)
content = response.json()

# Append the multiple returned file ids
for i in content['data']:
    file_ids.append(i['id'])

# Loop through the pagination token
# Same cursor token is applied as long as has_more variable is True
cursor = content['cursor']
has_more = content['has_more']
while has_more == True:
    loop_resp = requests.get(dir_uri + '?cursor=' + cursor, headers=headers)
    loop_cont = loop_resp.json()
    # print(loop_cont['cursor'])

    for i in loop_cont['data']:
        file_ids.append(i['id'])

    has_more = loop_cont['has_more']
    cursor = loop_cont['cursor']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 13
#      10 content = response.json()
#      12 # Append the multiple returned file ids
# ---> 13 for i in content['data']:
#      14     file_ids.append(i['id'])
#      16 # Loop through the pagination token
#      17 # Same cursor token is applied as long as has_more variable is True
#
# KeyError: 'data'

# %%
df = pd.DataFrame()
for id in file_ids:
    file_url = f'{os.getenv("kd_dns")}/2/drive/{os.getenv("kd_id")}/files/{id}/download'
    # Load table from kDrive directory into a raw DataFrame
    response = requests.get(file_url, headers=headers)
    raw_df = pd.read_excel(io.BytesIO(response.content), engine='openpyxl')

    # Remove first frow which subtitle from dataframe
    raw_df = raw_df.loc[1:]

    # Unpivot Table to set set a row for a measure
    raw_df = pd.melt(raw_df, id_vars=raw_df.columns[:6], value_vars=raw_df.columns[6:])
    raw_df.dropna(subset=['value'], inplace=True)
    raw_df = raw_df[raw_df['value'] != 0]
    raw_df = raw_df[raw_df['variable'] != 'Comment']
    raw_df['value'] = raw_df['value'].astype(float)
    raw_df.columns = map(str.lower, raw_df.columns)

    # Append raw DataFrame into final DataFrame
    df = pd.concat([df, raw_df], ignore_index=True)
    # convert birthday column to just date
    df['birthday'] = pd.to_datetime(df['birthday']).dt.date

# %%
df.head()
# Out:
#   Unnamed: 0_level_0   Unnamed: 1_level_0     Unnamed: 2_level_0  \
#   Unnamed: 0_level_1   Unnamed: 1_level_1     Unnamed: 2_level_1
# 0          Luan Jaun  BSC Young Boys, U15  Jul 22, 2024 17:00:00
# 1          Luan Jaun  BSC Young Boys, U15  Jul 22, 2024 17:00:00
# 2          Luan Jaun  BSC Young Boys, U15  Jul 22, 2024 17:00:00
# 3          Luan Jaun  BSC Young Boys, U15  Jul 23, 2024 10:00:00
# 4          Luan Jaun  BSC Young Boys, U15  Jul 24, 2024 17:00:00
#
#   Unnamed: 3_level_0     Unnamed: 4_level_0 Unnamed: 5_level_0  \
#   Unnamed: 3_level_1     Unnamed: 4_level_1 Unnamed: 5_level_1
# 0                NaN  TH Training U15 / U16    THT DZ auf BACK
# 1                NaN  TH Training U15 / U16   THT Einstieg SAB
# 2                NaN  TH Training U15 / U16   THT RZ im Winkel
# 3     BSC Young Boys          Training U-15             THT RZ
# 4     BSC Young Boys          Training U-15            THT BiT
#
#   Unnamed: 6_level_0   Parent Category Id Verhalten        ...        \
#   Unnamed: 6_level_1        Category Name      BACK CATCH  ...  STAY
# 0                NaN  4 Etwas anstrengend      15.0   NaN  ...   NaN
# 1                NaN             3 Mässig       NaN   NaN  ...   NaN
# 2                NaN  4 Etwas anstrengend       NaN   NaN  ...  15.0
# 3                NaN               0 Ruhe      45.0   NaN  ...  45.0
# 4                NaN                    6      45.0  45.0  ...   NaN
#
#                 DEF                                                \
#   Ball in die Tiefe Distanzschuss Hohe Bälle Nahdistanz Rote Zone
# 0               NaN          15.0        NaN        NaN       NaN
# 1               NaN           NaN        NaN        NaN       NaN
# 2               NaN           NaN        NaN        NaN      15.0
# 3               NaN           NaN        NaN        NaN      45.0
# 4              45.0           NaN        NaN        NaN       NaN
#
#                                             OFF                       \
#   Rück-/Querpassverteidigung Spielaufbau Zone 1 Spielaufbau Zone 2/3
# 0                        NaN                NaN                  NaN
# 1                        NaN               15.0                  NaN
# 2                        NaN                NaN                  NaN
# 3                        NaN                NaN                  NaN
# 4                        NaN                NaN                  NaN
#
#
#   Umschalten DEF-OFF
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 21 columns]

# %%
table_name = 'anthrophometrie'
cursor.sql(f"DROP TABLE IF EXISTS postgres_db.{table_name};")
# cursor.sql(f"CREATE TABLE IF NOT EXISTS postgres_db.{table_name} AS SELECT * FROM df;")

# %% [markdown]
# # Create a goalkeeper Dimension with current Team

# %%
goalies = pd.read_csv('/Users/matthiashugli/Downloads/keeper-export.csv', sep=',')
goalies['Player Name'] = goalies['Vorname'] + ' ' + goalies['Name']
goalies['Initialen'] = goalies['Vorname'].astype(str).str[0] + goalies['Name'].astype(str).str[0]
goalies['Geburtsdatum'] = pd.to_datetime(goalies['Geburtsdatum'], dayfirst=True)

table_name = 'goalies'
cursor.sql(f"DROP TABLE IF EXISTS postgres_db.{table_name};")
cursor.sql(f"CREATE TABLE IF NOT EXISTS postgres_db.{table_name} AS SELECT * FROM goalies")

# %% [markdown]
# # YB Data

# %%
df = pd.read_csv('/Users/matthiashugli/Downloads/s1_core_trm_player_unit_skills.csv', sep=';', header=[1,2], skiprows=[3])
df.head()
# Out:
#   Unnamed: 0_level_0   Unnamed: 1_level_0     Unnamed: 2_level_0  \
#   Unnamed: 0_level_1   Unnamed: 1_level_1     Unnamed: 2_level_1
# 0          Luan Jaun  BSC Young Boys, U15  Jul 22, 2024 17:00:00
# 1          Luan Jaun  BSC Young Boys, U15  Jul 22, 2024 17:00:00
# 2          Luan Jaun  BSC Young Boys, U15  Jul 22, 2024 17:00:00
# 3          Luan Jaun  BSC Young Boys, U15  Jul 23, 2024 10:00:00
# 4          Luan Jaun  BSC Young Boys, U15  Jul 24, 2024 17:00:00
#
#   Unnamed: 3_level_0     Unnamed: 4_level_0 Unnamed: 5_level_0  \
#   Unnamed: 3_level_1     Unnamed: 4_level_1 Unnamed: 5_level_1
# 0                NaN  TH Training U15 / U16    THT DZ auf BACK
# 1                NaN  TH Training U15 / U16   THT Einstieg SAB
# 2                NaN  TH Training U15 / U16   THT RZ im Winkel
# 3     BSC Young Boys          Training U-15             THT RZ
# 4     BSC Young Boys          Training U-15            THT BiT
#
#   Unnamed: 6_level_0   Parent Category Id Verhalten        ...        \
#   Unnamed: 6_level_1        Category Name      BACK CATCH  ...  STAY
# 0                NaN  4 Etwas anstrengend      15.0   NaN  ...   NaN
# 1                NaN             3 Mässig       NaN   NaN  ...   NaN
# 2                NaN  4 Etwas anstrengend       NaN   NaN  ...  15.0
# 3                NaN               0 Ruhe      45.0   NaN  ...  45.0
# 4                NaN                    6      45.0  45.0  ...   NaN
#
#                 DEF                                                \
#   Ball in die Tiefe Distanzschuss Hohe Bälle Nahdistanz Rote Zone
# 0               NaN          15.0        NaN        NaN       NaN
# 1               NaN           NaN        NaN        NaN       NaN
# 2               NaN           NaN        NaN        NaN      15.0
# 3               NaN           NaN        NaN        NaN      45.0
# 4              45.0           NaN        NaN        NaN       NaN
#
#                                             OFF                       \
#   Rück-/Querpassverteidigung Spielaufbau Zone 1 Spielaufbau Zone 2/3
# 0                        NaN                NaN                  NaN
# 1                        NaN               15.0                  NaN
# 2                        NaN                NaN                  NaN
# 3                        NaN                NaN                  NaN
# 4                        NaN                NaN                  NaN
#
#
#   Umschalten DEF-OFF
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 21 columns]

# %%
df = pd.read_csv('/Users/matthiashugli/Downloads/s1_core_trm_player_unit_skills.csv', sep=';')
df.columns = df.iloc[2, :8].tolist() + (df.iloc[0, 8:] + ',' + df.iloc[1, 8:]).tolist()
df = df.iloc[3:]
melt_df = df.melt(id_vars=df.columns[:8], value_vars=df.iloc[8:]) \
            .dropna(subset=['value']) \
            .reset_index()

melt_df.columns = melt_df.columns.str.replace(" ", "_")
melt_df[['verhalten', 'entscheid']] = melt_df['variable'].str.split(',', expand=True)
cursor.sql("DROP TABLE IF EXISTS skills_def; CREATE TEMPORARY TABLE skills_def AS SELECT * FROM melt_df;")

# %%
melt_df.head()
# Out:
#    index     Player Player's_current_team Training_Start_Datetime  \
# 0      0  Luan Jaun   BSC Young Boys, U15   Jul 22, 2024 17:00:00
# 1      3  Luan Jaun   BSC Young Boys, U15   Jul 23, 2024 10:00:00
# 2      4  Luan Jaun   BSC Young Boys, U15   Jul 24, 2024 17:00:00
# 3      5  Luan Jaun   BSC Young Boys, U15   Jul 30, 2024 17:00:00
# 4      7  Luan Jaun   BSC Young Boys, U15   Jul 31, 2024 10:00:00
#
#   Training_Team_Name          Training_Text Training_Unit_Short_Text  \
# 0                NaN  TH Training U15 / U16          THT DZ auf BACK
# 1     BSC Young Boys          Training U-15                   THT RZ
# 2     BSC Young Boys          Training U-15                  THT BiT
# 3     BSC Young Boys          Training U-15            THT Rote Zone
# 4     BSC Young Boys          Training U-15                 THT RQPV
#
#   Training_Unit_Description Training_Unit_Intensity_Text        variable  \
# 0                       NaN          4 Etwas anstrengend  Verhalten,BACK
# 1                       NaN                       0 Ruhe  Verhalten,BACK
# 2                       NaN                            6  Verhalten,BACK
# 3  - Orientierung im Winkel                       0 Ruhe  Verhalten,BACK
# 4                       NaN                       0 Ruhe  Verhalten,BACK
#
#   value  verhalten entscheid
# 0    15  Verhalten      BACK
# 1    45  Verhalten      BACK
# 2    45  Verhalten      BACK
# 3    15  Verhalten      BACK
# 4    40  Verhalten      BACK

# %%
cursor.sql("""SELECT sps.Index
           ,sps.Player AS Keeper
           ,CAST(strptime(sps.Training_Start_Datetime, '%b %-j, %Y %H:%M:%S') AS DATE) AS Datum
           ,CAST(strptime(sps.Training_Start_Datetime, '%b %-j, %Y %H:%M:%S') AS TIMESTAMP) AS Zeit
           ,sps.Training_Team_Name AS Trainingsteam
           ,sps.Training_Text AS Titel
           ,sps.Training_Unit_Short_Text AS Übung
           ,sps.Training_Unit_Description AS Notizen
           ,sps.Training_Unit_Intensity_Text AS Intensität
           ,sps.verhalten AS Kategorie
           ,sps.entscheid AS Skill
           ,'Spielaufbau' AS Entscheid
           ,CAST(sps.value AS INT) AS Dauer
           FROM skills_def sps
           WHERE sps.verhalten = 'OFF';           
           """)
# Out:
# ┌───────┬──────────────────┬────────────┬───┬───────────┬────────────────────┬─────────────┬───────┐
# │ index │      Keeper      │   Datum    │ … │ Kategorie │       Skill        │  Entscheid  │ Dauer │
# │ int64 │     varchar      │    date    │   │  varchar  │      varchar       │   varchar   │ int32 │
# ├───────┼──────────────────┼────────────┼───┼───────────┼────────────────────┼─────────────┼───────┤
# │  4371 │ Luan Jaun        │ 2024-01-22 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    15 │
# │  4376 │ Luan Jaun        │ 2024-01-30 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    35 │
# │  4388 │ Luan Jaun        │ 2024-01-16 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    15 │
# │  4391 │ Luan Jaun        │ 2024-01-25 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    25 │
# │  4396 │ Denis Martinovic │ 2024-01-17 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    30 │
# │  4400 │ Denis Martinovic │ 2024-01-22 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    15 │
# │  4403 │ Denis Martinovic │ 2024-01-24 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    25 │
# │  4409 │ Denis Martinovic │ 2024-01-06 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    45 │
# │  4433 │ Denis Martinovic │ 2024-01-24 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    10 │
# │  4436 │ Denis Martinovic │ 2024-01-01 │ … │ OFF       │ Spielaufbau Zone 1 │ Spielaufbau │    10 │
# │    ·  │        ·         │     ·      │ · │  ·        │         ·          │      ·      │     · │
# │    ·  │        ·         │     ·      │ · │  ·        │         ·          │      ·      │     · │
# │    ·  │        ·         │     ·      │ · │  ·        │         ·          │      ·      │     · │
# │  5387 │ Florian Reinhard │ 2024-01-24 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    60 │
# │  5413 │ David Lehmann    │ 2024-01-24 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    60 │
# │  5443 │ Robin Liechti    │ 2024-01-18 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    30 │
# │  5485 │ Cedrik Strupler  │ 2024-01-18 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    30 │
# │  5547 │ Leo Suter        │ 2024-01-24 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    60 │
# │  5574 │ Ramon Nussbaum   │ 2024-01-19 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    45 │
# │  5604 │ Kader Cherif     │ 2024-01-19 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    45 │
# │  5378 │ Florian Reinhard │ 2024-01-26 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    60 │
# │  5484 │ Cedrik Strupler  │ 2024-01-16 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    65 │
# │  5630 │ Jasha Bracher    │ 2024-01-13 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    35 │
# ├───────┴──────────────────┴────────────┴───┴───────────┴────────────────────┴─────────────┴───────┤
# │ 154 rows (20 shown)                                                         13 columns (7 shown) │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
cursor.sql("""SELECT sps.Index
           ,sps.Player AS Keeper
           ,CAST(strptime(sps.Training_Start_Datetime, '%b %-j, %Y %H:%M:%S') AS DATE) AS Datum
           ,CAST(strptime(sps.Training_Start_Datetime, '%b %-j, %Y %H:%M:%S') AS TIMESTAMP) AS Zeit
           ,sps.Training_Team_Name AS Trainingsteam
           ,sps.Training_Text AS Titel
           ,sps.Training_Unit_Short_Text AS Übung
           ,sps.Training_Unit_Description AS Notizen
           ,sps.Training_Unit_Intensity_Text AS Intensität
           ,sps.verhalten AS Kategorie
           ,sps.entscheid AS Skill
           ,ent.entscheid AS Entscheid
           ,CAST(sps.value AS INT) AS Dauer
           FROM skills_def sps
           LEFT JOIN (SELECT * FROM skills_def WHERE verhalten = 'Verhalten') ent 
           ON sps.Player = ent.Player
           AND sps.Training_Start_Datetime = ent.Training_Start_Datetime
           AND sps.Training_Unit_Short_Text = ent.Training_Unit_Short_Text
           WHERE sps.verhalten = 'DEF'
           
           UNION ALL
           
           SELECT sps.Index
           ,sps.Player AS Keeper
           ,CAST(strptime(sps.Training_Start_Datetime, '%b %-j, %Y %H:%M:%S') AS DATE) AS Datum
           ,CAST(strptime(sps.Training_Start_Datetime, '%b %-j, %Y %H:%M:%S') AS TIMESTAMP) AS Zeit
           ,sps.Training_Team_Name AS Trainingsteam
           ,sps.Training_Text AS Titel
           ,sps.Training_Unit_Short_Text AS Übung
           ,sps.Training_Unit_Description AS Notizen
           ,sps.Training_Unit_Intensity_Text AS Intensität
           ,sps.verhalten AS Kategorie
           ,sps.entscheid AS Skill
           ,'Spielaufbau' AS Entscheid
           ,CAST(sps.value AS INT) AS Dauer
           FROM skills_def sps
           WHERE sps.verhalten = 'OFF';           
           """)


# ['Keeper', 'Team', 'DatumZeit', 'Trainingsteam', 'Titel', 'Übung', 'Notizen', 'Intensität', 'Kategorie', 'Skill', 'Dauer']
# Out:
# ┌───────┬──────────────────┬────────────┬───┬───────────┬────────────────────┬─────────────┬───────┐
# │ index │      Keeper      │   Datum    │ … │ Kategorie │       Skill        │  Entscheid  │ Dauer │
# │ int64 │     varchar      │    date    │   │  varchar  │      varchar       │   varchar   │ int32 │
# ├───────┼──────────────────┼────────────┼───┼───────────┼────────────────────┼─────────────┼───────┤
# │  1752 │ Luan Jaun        │ 2024-01-24 │ … │ DEF       │ Ball in die Tiefe  │ GO          │    45 │
# │  1776 │ Denis Martinovic │ 2024-01-21 │ … │ DEF       │ Ball in die Tiefe  │ GO          │    30 │
# │  1777 │ Denis Martinovic │ 2024-01-22 │ … │ DEF       │ Ball in die Tiefe  │ STAY        │    30 │
# │  1783 │ Denis Martinovic │ 2024-01-26 │ … │ DEF       │ Ball in die Tiefe  │ STAY        │    25 │
# │  1800 │ Denis Martinovic │ 2024-01-02 │ … │ DEF       │ Ball in die Tiefe  │ CATCH       │    65 │
# │  1801 │ Denis Martinovic │ 2024-01-03 │ … │ DEF       │ Ball in die Tiefe  │ GO          │    15 │
# │  1803 │ Denis Martinovic │ 2024-01-06 │ … │ DEF       │ Ball in die Tiefe  │ STAY        │    25 │
# │  1817 │ Ruben Salchli    │ 2024-01-23 │ … │ DEF       │ Ball in die Tiefe  │ STAY        │    40 │
# │  1818 │ Ruben Salchli    │ 2024-01-24 │ … │ DEF       │ Ball in die Tiefe  │ STAY        │    30 │
# │  1836 │ Noam Wölfli      │ 2024-01-24 │ … │ DEF       │ Ball in die Tiefe  │ GO          │    45 │
# │    ·  │     ·            │     ·      │ · │  ·        │         ·          │ ·           │     · │
# │    ·  │     ·            │     ·      │ · │  ·        │         ·          │ ·           │     · │
# │    ·  │     ·            │     ·      │ · │  ·        │         ·          │ ·           │     · │
# │  5547 │ Leo Suter        │ 2024-01-24 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    60 │
# │  5561 │ Ramon Nussbaum   │ 2024-01-13 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    40 │
# │  5572 │ Ramon Nussbaum   │ 2024-01-16 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    65 │
# │  5574 │ Ramon Nussbaum   │ 2024-01-19 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    45 │
# │  5594 │ Kader Cherif     │ 2024-01-13 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    40 │
# │  5604 │ Kader Cherif     │ 2024-01-19 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    45 │
# │  5620 │ Jasha Bracher    │ 2024-01-23 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    20 │
# │  5630 │ Jasha Bracher    │ 2024-01-13 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    35 │
# │  5631 │ Jasha Bracher    │ 2024-01-14 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │     5 │
# │  5647 │ Jasha Bracher    │ 2024-01-16 │ … │ OFF       │ Umschalten DEF-OFF │ Spielaufbau │    50 │
# ├───────┴──────────────────┴────────────┴───┴───────────┴────────────────────┴─────────────┴───────┤
# │ 889 rows (20 shown)                                                         13 columns (7 shown) │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df = pd.read_csv('/Users/matthiashugli/Downloads/s1_core_trm_player_unit_skills.csv', sep=';', header=[1,2], skiprows=[3])
df \
            .set_index([('Unnamed: 0_level_0', 'Unnamed: 0_level_1'), ('Unnamed: 1_level_0', 'Unnamed: 1_level_1'), 
                        ('Unnamed: 2_level_0', 'Unnamed: 2_level_1'), ('Unnamed: 3_level_0', 'Unnamed: 3_level_1'), 
                        ('Unnamed: 4_level_0', 'Unnamed: 4_level_1'), ('Unnamed: 5_level_0', 'Unnamed: 5_level_1'),
                         ('Unnamed: 6_level_0', 'Unnamed: 6_level_1'), ('Parent Category Id', 'Category Name')])
# Out:
#                                                                                                                                                                                                                                                                                                                                    Verhalten  \
#                                                                                                                                                                                                                                                                                                                                         BACK
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                      15.0
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                      15.0
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
# ...                                                                                                                                                                                                                                                                                                                                      ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                      30.0
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                      30.0
#
#                                                                                                                                                                                                                                                                                                                                           \
#                                                                                                                                                                                                                                                                                                                                    CATCH
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                  15.0
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                   NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                  15.0
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                   NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                  15.0
# ...                                                                                                                                                                                                                                                                                                                                  ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                              NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                  30.0
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                              NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                  75.0
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                  30.0
#
#                                                                                                                                                                                                                                                                                                                                           \
#                                                                                                                                                                                                                                                                                                                                       GO
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                  15.0
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                   NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                  15.0
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                   NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                  15.0
# ...                                                                                                                                                                                                                                                                                                                                  ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                              NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                   NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                              NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                  75.0
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                   NaN
#
#                                                                                                                                                                                                                                                                                                                                           \
#                                                                                                                                                                                                                                                                                                                                     STAY
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                   NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                  15.0
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                   NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                  15.0
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                   NaN
# ...                                                                                                                                                                                                                                                                                                                                  ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                              NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                   NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                              NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                  75.0
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                   NaN
#
#                                                                                                                                                                                                                                                                                                                                                  DEF  \
#                                                                                                                                                                                                                                                                                                                                    Ball in die Tiefe
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                              15.0
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                               NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                              15.0
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                               NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                              15.0
# ...                                                                                                                                                                                                                                                                                                                                              ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                          NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                               NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                          NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                               NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                               NaN
#
#                                                                                                                                                                                                                                                                                                                                                   \
#                                                                                                                                                                                                                                                                                                                                    Distanzschuss
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                           NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                          15.0
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                           NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                          15.0
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                           NaN
# ...                                                                                                                                                                                                                                                                                                                                          ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                      NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                           NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                      NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                           NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                           NaN
#
#                                                                                                                                                                                                                                                                                                                                                \
#                                                                                                                                                                                                                                                                                                                                    Hohe Bälle
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                        NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                        NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                        NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                        NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                        NaN
# ...                                                                                                                                                                                                                                                                                                                                       ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                   NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       30.0
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                   NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                        NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       30.0
#
#                                                                                                                                                                                                                                                                                                                                                \
#                                                                                                                                                                                                                                                                                                                                    Nahdistanz
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                        NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                        NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                        NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                        NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                        NaN
# ...                                                                                                                                                                                                                                                                                                                                       ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                   NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                        NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                   NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                        NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                        NaN
#
#                                                                                                                                                                                                                                                                                                                                               \
#                                                                                                                                                                                                                                                                                                                                    Rote Zone
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
# ...                                                                                                                                                                                                                                                                                                                                      ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       NaN
#
#                                                                                                                                                                                                                                                                                                                                                                \
#                                                                                                                                                                                                                                                                                                                                    Rück-/Querpassverteidigung
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                                        NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                                        NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                                        NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                                        NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                                        NaN
# ...                                                                                                                                                                                                                                                                                                                                                       ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                                   NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                                        NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                                   NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                                       75.0
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                                        NaN
#
#                                                                                                                                                                                                                                                                                                                                     ...  \
#                                                                                                                                                                                                                                                                                                                                     ...
# ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                      NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                           NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                      NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                           NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                           NaN
#
#                                                                                                                                                                                                                                                                                                                                               \
#                                                                                                                                                                                                                                                                                                                                    Passspiel
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
# ...                                                                                                                                                                                                                                                                                                                                      ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       NaN
#
#                                                                                                                                                                                                                                                                                                                                                    \
#                                                                                                                                                                                                                                                                                                                                    TE unter Druck
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                            NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                            NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                            NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                            NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                            NaN
# ...                                                                                                                                                                                                                                                                                                                                           ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                       NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                            NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                       NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                            NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                            NaN
#
#
#                                                                                                                                                                                                                                                                                                                                    Torschuss
# (Unnamed: 0_level_0, Unnamed: 0_level_1) (Unnamed: 1_level_0, Unnamed: 1_level_1) (Unnamed: 2_level_0, Unnamed: 2_level_1) (Unnamed: 3_level_0, Unnamed: 3_level_1) (Unnamed: 4_level_0, Unnamed: 4_level_1) (Unnamed: 5_level_0, Unnamed: 5_level_1) (Unnamed: 6_level_0, Unnamed: 6_level_1) (Parent Category Id, Category Name)
# Jara Ackermann                           ♀ BSC YB-Frauen                          Sep 4, 2024 10:30:00                     BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 11, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
#                                                                                                                                                                                                              TH DS                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 18, 2024 10:30:00                    BSC Young Boys                           Individual Training                      TH BiT                                   NaN                                      4 Etwas anstrengend                       NaN
# ...                                                                                                                                                                                                                                                                                                                                      ...
# Felix Stuber                             BSC Young Boys, U16                      Sep 16, 2024 17:30:00                    NaN                                      THT OFF                                  THT OFF Z1                               NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 18, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 19, 2024 17:00:00                    NaN                                      THT OFF                                  TH OFF Z1                                NaN                                      3 Mässig                                  NaN
#                                                                                   Sep 23, 2024 16:15:00                    NaN                                      TH Training U15/16                       TH RQPV                                  NaN                                      4 Etwas anstrengend                       NaN
#                                                                                   Sep 24, 2024 17:30:00                    BSC Young Boys                           Training U-16                            TH HB                                    NaN                                      4 Etwas anstrengend                       NaN
#
# [512 rows x 29 columns]

# %%
df = pd.read_csv('/Users/matthiashugli/Downloads/s1_core_trm_player_unit_skills.csv', sep=';', header=[1,2], skiprows=[3])
melt_df = df \
            .set_index([('Unnamed: 0_level_0', 'Unnamed: 0_level_1'), ('Unnamed: 1_level_0', 'Unnamed: 1_level_1'), 
                        ('Unnamed: 2_level_0', 'Unnamed: 2_level_1'), ('Unnamed: 3_level_0', 'Unnamed: 3_level_1'), 
                        ('Unnamed: 4_level_0', 'Unnamed: 4_level_1'), ('Unnamed: 5_level_0', 'Unnamed: 5_level_1'),
                         ('Unnamed: 6_level_0', 'Unnamed: 6_level_1'), ('Parent Category Id', 'Category Name')]) \
            .melt(ignore_index=False) \
            .dropna(subset=['value']) \
            .reset_index()

melt_df.columns = ['Keeper', 'Team', 'DatumZeit', 'Trainingsteam', 'Titel', 'Übung', 'Notizen', 'Intensität', 'Kategorie', 'Skill', 'Dauer']
# Split skills and decisions into own DataFrames and concat on the column axis
def_df = melt_df[melt_df['Kategorie'] == 'DEF']
verhalten_df = melt_df[melt_df['Kategorie'] == 'Verhalten']
defensive_skills = verhalten_df.merge(def_df, left_on=['Keeper', 'DatumZeit', 'Übung'], right_on=['Keeper', 'DatumZeit', 'Übung'], suffixes=[None, 'DEF']).reset_index()

defensive_skills = defensive_skills[['Keeper', 'Team', 'DatumZeit', 'Trainingsteam', 'Titel', 'Übung',
                        'Notizen', 'Intensität', 'Skill', 'KategorieDEF', 'SkillDEF', 'Dauer']].copy()
defensive_skills = defensive_skills.rename(columns={'Skill': 'Verhalten', 'KategorieDEF': 'DEF/OFF', 'SkillDEF': 'Spielsituation'})

# Filter the offensive content
off_df = melt_df[melt_df['Kategorie'] == 'OFF']
off_df = off_df.rename(columns={'Kategorie': 'DEF/OFF', 'Skill': 'Spielsituation'})

# Concat to the defensive DataFrame on the row axis
th_skills = pd.concat([defensive_skills, off_df], sort=False)

# Convert columns to their data type
th_skills['Datum'] = pd.to_datetime(th_skills.DatumZeit).dt.date
th_skills['Zeit'] = pd.to_datetime(th_skills.DatumZeit).dt.time
th_skills.drop(columns=['DatumZeit'], inplace=True)

# Export DataFrame to CSV
th_skills.to_csv('/Users/matthiashugli/kDrive/goalkeeping/💛🖤 YB Nachwuchs/csv_th_skill.csv', index=False, sep=";")
#df[df.iloc[:, 0] == 'Marco Iseli']
th_skills[th_skills['Keeper'] == 'Nik Lyoth']
# Out:
#          Keeper                 Team   Trainingsteam  \
# 55    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 56    Nik Lyoth  FE-14 PSA Bern, U14  BSC Young Boys
# 57    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 58    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 59    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 60    Nik Lyoth  FE-14 PSA Bern, U14  BSC Young Boys
# 61    Nik Lyoth  FE-14 PSA Bern, U14  BSC Young Boys
# 62    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 63    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 64    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 65    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 66    Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 213   Nik Lyoth  FE-14 PSA Bern, U14  BSC Young Boys
# 214   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 215   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 216   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 217   Nik Lyoth  FE-14 PSA Bern, U14  BSC Young Boys
# 218   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 219   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 220   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 221   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 415   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 416   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 574   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 575   Nik Lyoth  FE-14 PSA Bern, U14  BSC Young Boys
# 576   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 577   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 578   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 579   Nik Lyoth  FE-14 PSA Bern, U14  BSC Young Boys
# 580   Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 1012  Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 1013  Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 1014  Nik Lyoth  FE-14 PSA Bern, U14             NaN
# 1093  Nik Lyoth  FE-14 PSA Bern, U14             NaN
#
#                             Titel                                    Übung  \
# 55               TH Training FE14                THT RZ (Winkel / Zentral)
# 56                  Training U-15                                 THT RQPV
# 57          TH Training FE14 - TL                                 THT RQPV
# 58    TH Training FE14 / U15 - TL                              THT FE14 RZ
# 59               TH Training FE14                                 THT RQPV
# 60                  Training U-15                            THT RZ / RQPV
# 61                  Training U-15  THT Hohe Bälle (Spielform Flankenspiel)
# 62               TH Training FE14                        THT Distanzschuss
# 63    THT + Integriert FE14 / U15         THT RQPV mit organisiertem Block
# 64               TH Training FE14                           THT Hohe Bälle
# 65               TH Training FE14                                   THT DS
# 66               TH Training FE14                 THT Hohe Bälle (Eckball)
# 213                 Training U-15                                 THT RQPV
# 214         TH Training FE14 - TL                                 THT RQPV
# 215   TH Training FE14 / U15 - TL                 THT Umschalten DEF / NDZ
# 216              TH Training FE14                                 THT RQPV
# 217                 Training U-15  THT Hohe Bälle (Spielform Flankenspiel)
# 218              TH Training FE14                           THT Hohe Bälle
# 219   THT + Integriert FE14 / U15         THT RQPV mit organisiertem Block
# 220              TH Training FE14                           THT Hohe Bälle
# 221              TH Training FE14                 THT Hohe Bälle (Eckball)
# 415         TH Training FE14 - TL                                 THT RQPV
# 416   TH Training FE14 / U15 - TL                 THT Umschalten DEF / NDZ
# 574              TH Training FE14                THT RZ (Winkel / Zentral)
# 575                 Training U-15                                 THT RQPV
# 576   TH Training FE14 / U15 - TL                 THT Umschalten DEF / NDZ
# 577   TH Training FE14 / U15 - TL                              THT FE14 RZ
# 578              TH Training FE14                                 THT RQPV
# 579                 Training U-15                            THT RZ / RQPV
# 580              TH Training FE14                         THT RZ im Winkel
# 1012             TH Training FE14                THT SAB Druck suchen (TE)
# 1013  THT + Integriert FE14 / U15         THT RQPV mit organisiertem Block
# 1014             TH Training FE14                           THT SAB Zone 1
# 1093             TH Training FE14                           THT Hohe Bälle
#
#                                            Notizen           Intensität  \
# 55                                             NaN                    6
# 56                                             NaN               0 Ruhe
# 57                                             NaN                    6
# 58                                             NaN  4 Etwas anstrengend
# 59                                             NaN        5 Anstrengend
# 60                                             NaN  4 Etwas anstrengend
# 61                                             NaN        5 Anstrengend
# 62                                Hechten one-step        5 Anstrengend
# 63                                             NaN  4 Etwas anstrengend
# 64                                             NaN               0 Ruhe
# 65                                             NaN  4 Etwas anstrengend
# 66    Eckball Organisation,\nZusammenspiel Blocker                    6
# 213                                            NaN               0 Ruhe
# 214                                            NaN                    6
# 215                                            NaN        5 Anstrengend
# 216                                            NaN        5 Anstrengend
# 217                                            NaN        5 Anstrengend
# 218       Hoher Ball zentral, Explosivität reaktiv        5 Anstrengend
# 219                                            NaN  4 Etwas anstrengend
# 220                                            NaN               0 Ruhe
# 221   Eckball Organisation,\nZusammenspiel Blocker                    6
# 415                                            NaN                    6
# 416                                            NaN        5 Anstrengend
# 574                                            NaN                    6
# 575                                            NaN               0 Ruhe
# 576                                            NaN        5 Anstrengend
# 577                                            NaN  4 Etwas anstrengend
# 578                                            NaN        5 Anstrengend
# 579                                            NaN  4 Etwas anstrengend
# 580                                            NaN               0 Ruhe
# 1012                                           NaN  4 Etwas anstrengend
# 1013                                           NaN  4 Etwas anstrengend
# 1014                                           NaN             3 Mässig
# 1093      Hoher Ball zentral, Explosivität reaktiv        5 Anstrengend
#
#      Verhalten DEF/OFF              Spielsituation  Dauer       Datum  \
# 55        BACK     DEF                   Rote Zone   90.0  2024-07-29
# 56        BACK     DEF  Rück-/Querpassverteidigung   40.0  2024-07-31
# 57        BACK     DEF  Rück-/Querpassverteidigung   75.0  2024-08-06
# 58        BACK     DEF                   Rote Zone   35.0  2024-08-07
# 59        BACK     DEF  Rück-/Querpassverteidigung   75.0  2024-08-12
# 60        BACK     DEF                   Rote Zone   60.0  2024-08-13
# 61        BACK     DEF                  Hohe Bälle   45.0  2024-08-14
# 62        BACK     DEF               Distanzschuss   30.0  2024-08-26
# 63        BACK     DEF  Rück-/Querpassverteidigung   60.0  2024-08-27
# 64        BACK     DEF                  Hohe Bälle   90.0  2024-09-09
# 65        BACK     DEF               Distanzschuss   15.0  2024-09-16
# 66        BACK     DEF                  Hohe Bälle   60.0  2024-09-16
# 213      CATCH     DEF  Rück-/Querpassverteidigung   40.0  2024-07-31
# 214      CATCH     DEF  Rück-/Querpassverteidigung   75.0  2024-08-06
# 215      CATCH     DEF                  Nahdistanz   40.0  2024-08-07
# 216      CATCH     DEF  Rück-/Querpassverteidigung   75.0  2024-08-12
# 217      CATCH     DEF                  Hohe Bälle   45.0  2024-08-14
# 218      CATCH     DEF                  Hohe Bälle   60.0  2024-08-26
# 219      CATCH     DEF  Rück-/Querpassverteidigung   60.0  2024-08-27
# 220      CATCH     DEF                  Hohe Bälle   90.0  2024-09-09
# 221      CATCH     DEF                  Hohe Bälle   60.0  2024-09-16
# 415         GO     DEF  Rück-/Querpassverteidigung   75.0  2024-08-06
# 416         GO     DEF                  Nahdistanz   40.0  2024-08-07
# 574       STAY     DEF                   Rote Zone   90.0  2024-07-29
# 575       STAY     DEF  Rück-/Querpassverteidigung   40.0  2024-07-31
# 576       STAY     DEF                  Nahdistanz   40.0  2024-08-07
# 577       STAY     DEF                   Rote Zone   35.0  2024-08-07
# 578       STAY     DEF  Rück-/Querpassverteidigung   75.0  2024-08-12
# 579       STAY     DEF                   Rote Zone   60.0  2024-08-13
# 580       STAY     DEF                   Rote Zone   90.0  2024-09-02
# 1012       NaN     OFF          Spielaufbau Zone 1   15.0  2024-08-12
# 1013       NaN     OFF          Spielaufbau Zone 1   60.0  2024-08-27
# 1014       NaN     OFF          Spielaufbau Zone 1   15.0  2024-09-16
# 1093       NaN     OFF          Umschalten DEF-OFF   60.0  2024-08-26
#
#           Zeit
# 55    09:00:00
# 56    10:00:00
# 57    15:00:00
# 58    15:00:00
# 59    17:00:00
# 60    17:00:00
# 61    17:00:00
# 62    17:00:00
# 63    17:00:00
# 64    17:00:00
# 65    17:00:00
# 66    17:00:00
# 213   10:00:00
# 214   15:00:00
# 215   09:30:00
# 216   17:00:00
# 217   17:00:00
# 218   17:00:00
# 219   17:00:00
# 220   17:00:00
# 221   17:00:00
# 415   15:00:00
# 416   09:30:00
# 574   09:00:00
# 575   10:00:00
# 576   09:30:00
# 577   15:00:00
# 578   17:00:00
# 579   17:00:00
# 580   17:00:00
# 1012  17:00:00
# 1013  17:00:00
# 1014  17:00:00
# 1093  17:00:00

# %%
table_name = 'trainings'
cursor.sql(f"DROP TABLE IF EXISTS postgres_db.{table_name};")
cursor.sql(f"CREATE TABLE IF NOT EXISTS postgres_db.{table_name} AS SELECT * FROM th_skills")

# %% [markdown]
# ## Anwesenheiten

# %%
df = pd.read_csv('/Users/matthiashugli/Downloads/s1_CORE_TRAINING_PARTICIPANTS_V2_CV.csv', sep=';')
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace(":", "")
df['Stufe'] = [x[-1] for x in df['Team'].str.split(', ')]
df['Datum'] = pd.to_datetime(df.Training_Start_Datetime).dt.date
df['Zeit'] = pd.to_datetime(df.Training_Start_Datetime).dt.time
#df.drop(columns=['Training_Start_Datetime'], inplace=True)
df.head()
# Out:
#        Person Position                             Team     Training_Text  \
# 0  Jan Schmid      Tor  FE-13 BSC YOUNG BOYS black, U13  TH Training FE13
# 1  Jan Schmid      Tor  FE-13 BSC YOUNG BOYS black, U13  TH Training FE13
# 2  Jan Schmid      Tor  FE-13 BSC YOUNG BOYS black, U13  TH Training FE13
# 3  Jan Schmid      Tor  FE-13 BSC YOUNG BOYS black, U13  TH Training FE13
# 4  Jan Schmid      Tor  FE-13 BSC YOUNG BOYS black, U13  TH Training FE13
#
#   Training_Team Training_Start_Datetime Abscence_Reason  Unnamed_7 Stufe  \
# 0           NaN   Jul 31, 2024 15:15:00          Privat          0   U13
# 1           NaN    Aug 28, 2024 3:00:00          Privat          0   U13
# 2           NaN    Sep 4, 2024 15:00:00             NaN          1   U13
# 3           NaN    Sep 11, 2024 9:00:00             NaN          1   U13
# 4           NaN    Sep 18, 2024 9:00:00             NaN          1   U13
#
#         Datum      Zeit
# 0  2024-07-31  15:15:00
# 1  2024-08-28  03:00:00
# 2  2024-09-04  15:00:00
# 3  2024-09-11  09:00:00
# 4  2024-09-18  09:00:00

# %%
# cursor.sql("SELECT Training_Start_Datetime FROM df (TIMESTAMPFORMAT '%b %-j, %Y %h:%M:%S')")
# cursor.sql("SELECT strptime(Training_Start_Datetime, '%b %-j, %Y %h:%M:%S') from df")
cursor.sql("SELECT try_strptime(Training_Start_Datetime, '%b %-j, %Y %h:%M:%S') from df")
# Out:
# ┌──────────────────────────────────────────────────────────────┐
# │ try_strptime(Training_Start_Datetime, '%B %-j, %Y %h:%M:%S') │
# │                          timestamp                           │
# ├──────────────────────────────────────────────────────────────┤
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │  ·                                                           │
# │  ·                                                           │
# │  ·                                                           │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# │ NULL                                                         │
# ├──────────────────────────────────────────────────────────────┤
# │                     794 rows (20 shown)                      │
# └──────────────────────────────────────────────────────────────┘

# %%
cursor.sql("""
            SELECT Person AS Keeper
             ,CAST(Datum AS DATE) AS Datum
            ,CAST(Zeit AS TIME) AS Zeit
            ,Position AS Position
            ,Team AS Team
            ,Stufe AS Stufe
            ,Training_Text AS Titel
            ,Training_Team AS Trainingsteam
            ,Abscence_Reason AS Abwesenheitsgrund
            ,CAST(Unnamed_7 AS INT) AS Anwesend
            FROM df limit 10;
           """)

# df[['Keeper', 'Position', 'Team', 'Stufe', 'Titel', 'Trainingsteam', 'Datum', 'Abwesenheitsgrund', 'Anwesend']]
# Out:
# ┌────────────┬────────────┬──────────┬──────────┬───┬──────────────────┬───────────────┬───────────────────┬──────────┐
# │   Keeper   │   Datum    │   Zeit   │ Position │ … │      Titel       │ Trainingsteam │ Abwesenheitsgrund │ Anwesend │
# │  varchar   │    date    │   time   │ varchar  │   │     varchar      │    varchar    │      varchar      │  int32   │
# ├────────────┼────────────┼──────────┼──────────┼───┼──────────────────┼───────────────┼───────────────────┼──────────┤
# │ Jan Schmid │ 2024-07-31 │ 15:15:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ Privat            │        0 │
# │ Jan Schmid │ 2024-08-28 │ 03:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ Privat            │        0 │
# │ Jan Schmid │ 2024-09-04 │ 15:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# │ Jan Schmid │ 2024-09-11 │ 09:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# │ Jan Schmid │ 2024-09-18 │ 09:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# │ Jan Schmid │ 2024-10-02 │ 09:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# │ Jan Schmid │ 2024-10-09 │ 09:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# │ Jan Schmid │ 2024-10-16 │ 09:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# │ Jan Schmid │ 2024-10-23 │ 09:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# │ Jan Schmid │ 2024-10-30 │ 09:00:00 │ Tor      │ … │ TH Training FE13 │ NULL          │ NULL              │        1 │
# ├────────────┴────────────┴──────────┴──────────┴───┴──────────────────┴───────────────┴───────────────────┴──────────┤
# │ 10 rows                                                                                        10 columns (8 shown) │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df = pd.read_csv('/Users/matthiashugli/Downloads/s1_CORE_TRAINING_PARTICIPANTS_V2_CV.csv', sep=';')
df['Stufe'] = [x[-1] for x in df['Team'].str.split(', ')]

# Convert columns to their data type
df['Datum'] = pd.to_datetime(df.Datum).dt.date
participation = df[['Keeper', 'Position', 'Team', 'Stufe', 'Titel', 'Trainingsteam', 'Datum', 'Abwesenheitsgrund', 'Anwesend']]
participation.head()

table_name = 'anwesenheiten'
cursor.sql(f"DROP TABLE IF EXISTS postgres_db.{table_name};")
cursor.sql(f"CREATE TABLE IF NOT EXISTS postgres_db.{table_name} AS SELECT * FROM participation")

# %% [markdown]
# # Date Table

# %%
cursor.sql("""
            WITH date_range AS (
                SELECT
                    MIN(Datum) AS start_date,
                    MAX(Datum) AS end_date
                FROM th_skills
            ),
            dates AS (
                SELECT
                    start_date + INTERVAL '1 day' * (ROW_NUMBER() OVER (ORDER BY seq) - 1) AS date
                FROM
                    (SELECT start_date, end_date FROM date_range) AS dr
                JOIN
                    (SELECT seq FROM range(0, (SELECT EXTRACT(day FROM end_date - start_date) FROM date_range))) AS r ON true
            )
            SELECT
                date,
                EXTRACT(year FROM date) AS year,
                EXTRACT(month FROM date) AS month,
                TO_CHAR(date, 'Month') AS month_name,
                EXTRACT(day FROM date) AS day,
                TO_CHAR(date, 'Day') AS day_name,
                EXTRACT(doy FROM date) AS day_number,
                TO_CHAR(date, 'YYYY-MM') AS year_month
            FROM dates
            ORDER BY date;
           """)
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[444], line 1
# ----> 1 cursor.sql("""
#       2             WITH date_range AS (
#       3                 SELECT
#       4                     MIN(Datum) AS start_date,
#       5                     MAX(Datum) AS end_date
#       6                 FROM th_skills
#       7             ),
#       8             dates AS (
#       9                 SELECT
#      10                     start_date + INTERVAL '1 day' * (ROW_NUMBER() OVER (ORDER BY seq) - 1) AS date
#      11                 FROM
#      12                     (SELECT start_date, end_date FROM date_range) AS dr
#      13                 JOIN
#      14                     (SELECT seq FROM range(0, (SELECT EXTRACT(day FROM end_date - start_date) FROM date_range))) AS r ON true
#      15             )
#      16             SELECT
#      17                 date,
#      18                 EXTRACT(year FROM date) AS year,
#      19                 EXTRACT(month FROM date) AS month,
#      20                 TO_CHAR(date, 'Month') AS month_name,
#      21                 EXTRACT(day FROM date) AS day,
#      22                 TO_CHAR(date, 'Day') AS day_name,
#      23                 EXTRACT(doy FROM date) AS day_number,
#      24                 TO_CHAR(date, 'YYYY-MM') AS year_month
#      25             FROM dates
#      26             ORDER BY date;
#      27            """)
#
# CatalogException: Catalog Error: Table with name th_skills does not exist!
# Did you mean "skills_def"?

# %% [markdown]
# # Kdrive API

# %%
import pandas as pd
from dotenv import load_dotenv
import os
import io
import requests
import http
import csv
## Load dotenv variables
load_dotenv()

headers = {
'Authorization': 'Bearer ' + os.getenv("kd_token"),
'Content-Type': 'application/json',
}

def find_delimiter(text):
    sniffer = csv.Sniffer()
    delimiter = sniffer.sniff(text).delimiter
    return delimiter

kd_dns = os.getenv("kd_dns")
kd_id = os.getenv("kd_id")
conn = http.client.HTTPSConnection('api.infomaniak.com')
r = requests.get(url=f'{kd_dns}2/drive/{kd_id}/files/5476/download', headers=headers)
text = r.text
delimiter = find_delimiter(text)
df = pd.read_csv(io.StringIO(r.text), sep=';')

# %%
import duckdb
csvfile = io.BytesIO(r.content)
duckdb.sql("SELECT * FROM read_csv(csvfile);")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[227], line 3
#       1 import duckdb
#       2 csvfile = io.BytesIO(r.content)
# ----> 3 duckdb.sql("SELECT * FROM read_csv(csvfile);")
#
# File ~/Virtualenvs/football-analysis/venv/lib/python3.11/site-packages/duckdb/__init__.py:457, in sql(query, **kwargs)
#     455 else:
#     456     conn = duckdb.connect(":default:")
# --> 457 return conn.sql(query, **kwargs)
#
# IOException: IO Error: No files found that match the pattern "csvfile"

# %%
skills = pd.read_csv(io.StringIO(r.text), sep=delimiter, skiprows=2)

# %%
skills.dropna(axis=1, how='all')
# Out:
#          Unnamed: 0             Unnamed: 1               Unnamed: 2  \
# 0            Player  Player's current team  Training Start Datetime
# 1    Jara Ackermann        ♀ BSC YB-Frauen     Sep 4, 2024 10:30:00
# 2    Jara Ackermann        ♀ BSC YB-Frauen     Sep 4, 2024 10:30:00
# 3    Jara Ackermann        ♀ BSC YB-Frauen    Sep 11, 2024 10:30:00
# 4    Jara Ackermann        ♀ BSC YB-Frauen    Sep 11, 2024 10:30:00
# ..              ...                    ...                      ...
# 508    Felix Stuber    BSC Young Boys, U16    Sep 16, 2024 17:30:00
# 509    Felix Stuber    BSC Young Boys, U16    Sep 18, 2024 17:30:00
# 510    Felix Stuber    BSC Young Boys, U16    Sep 19, 2024 17:00:00
# 511    Felix Stuber    BSC Young Boys, U16    Sep 23, 2024 16:15:00
# 512    Felix Stuber    BSC Young Boys, U16    Sep 24, 2024 17:30:00
#
#              Unnamed: 3           Unnamed: 4                Unnamed: 5  \
# 0    Training Team Name        Training Text  Training Unit Short Text
# 1        BSC Young Boys  Individual Training                    TH BiT
# 2        BSC Young Boys  Individual Training                     TH DS
# 3        BSC Young Boys  Individual Training                    TH BiT
# 4        BSC Young Boys  Individual Training                     TH DS
# ..                  ...                  ...                       ...
# 508                 NaN              THT OFF                THT OFF Z1
# 509      BSC Young Boys        Training U-16                     TH HB
# 510                 NaN              THT OFF                 TH OFF Z1
# 511                 NaN   TH Training U15/16                   TH RQPV
# 512      BSC Young Boys        Training U-16                     TH HB
#
#                     Unnamed: 6                 Category Name  BACK  CATCH  \
# 0    Training Unit Description  Training Unit Intensity Text   NaN    NaN
# 1                          NaN           4 Etwas anstrengend   NaN   15.0
# 2                          NaN           4 Etwas anstrengend  15.0    NaN
# 3                          NaN           4 Etwas anstrengend   NaN   15.0
# 4                          NaN           4 Etwas anstrengend  15.0    NaN
# ..                         ...                           ...   ...    ...
# 508                        NaN                      3 Mässig   NaN    NaN
# 509                        NaN           4 Etwas anstrengend  30.0   30.0
# 510                        NaN                      3 Mässig   NaN    NaN
# 511                        NaN           4 Etwas anstrengend   NaN   75.0
# 512                        NaN           4 Etwas anstrengend  30.0   30.0
#
#      ...  EXPLOSIVITÄT  KOGNITIV  RUMPFKRAFT  Ballmitnahme  Dribbling  \
# 0    ...           NaN       NaN         NaN           NaN        NaN
# 1    ...           NaN       NaN         NaN           NaN        NaN
# 2    ...           NaN       NaN         NaN           NaN        NaN
# 3    ...           NaN       NaN         NaN           NaN        NaN
# 4    ...           NaN       NaN         NaN           NaN        NaN
# ..   ...           ...       ...         ...           ...        ...
# 508  ...           NaN       NaN         NaN           NaN        NaN
# 509  ...           NaN       NaN         NaN           NaN        NaN
# 510  ...           NaN       NaN         NaN           NaN        NaN
# 511  ...           NaN       NaN         NaN           NaN        NaN
# 512  ...           NaN       NaN         NaN           NaN        NaN
#
#      Flugball Flanken  Kopfballspiel  Passspiel  TE unter Druck  Torschuss
# 0                 NaN            NaN        NaN             NaN        NaN
# 1                 NaN            NaN        NaN             NaN        NaN
# 2                 NaN            NaN        NaN             NaN        NaN
# 3                 NaN            NaN        NaN             NaN        NaN
# 4                 NaN            NaN        NaN             NaN        NaN
# ..                ...            ...        ...             ...        ...
# 508               NaN            NaN        NaN             NaN        NaN
# 509               NaN            NaN        NaN             NaN        NaN
# 510               NaN            NaN        NaN             NaN        NaN
# 511               NaN            NaN        NaN             NaN        NaN
# 512               NaN            NaN        NaN             NaN        NaN
#
# [513 rows x 37 columns]

# %%
import duckdb
skills_unpivot = duckdb.sql("""
UNPIVOT skills
ON COLUMNS(* EXCLUDE ('Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 
           'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 
           'Unnamed: 6', 'Category Name'))
INTO
    NAME Kategorie
    VALUE Minuten;
           """)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[253], line 2
#       1 import duckdb
# ----> 2 skills_unpivot = duckdb.sql("""
#       3 UNPIVOT skills
#       4 ON COLUMNS(* EXCLUDE ('Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2',
#       5            'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#       6            'Unnamed: 6', 'Category Name'))
#       7 INTO
#       8     NAME Kategorie
#       9     VALUE Minuten;
#      10            """)
#
# File ~/Virtualenvs/football-analysis/venv/lib/python3.11/site-packages/duckdb/__init__.py:457, in sql(query, **kwargs)
#     455 else:
#     456     conn = duckdb.connect(":default:")
# --> 457 return conn.sql(query, **kwargs)
#
# BinderException: Binder Error: Column "Category Name" in EXCLUDE list not found in FROM clause

# %%
cursor.sql("DROP TABLE IF EXISTS skills_db;")
skills_db = cursor.sql("""CREATE TABLE IF NOT EXISTS skills_db 
           (Keeper varchar not null
           ,Team varchar not null
           ,DatumZeit varchar not null
           ,Trainingsteam varchar null
           ,Titel varchar null
           ,Übung varchar null
           ,Notizen varchar null
           ,Intensität varchar null
           ,Kategorie varchar not null
           ,Dauer real not null)""")

# %%
skills = kdrive.read_csv(5476)

# %%
cursor.sql("ALTER TABLE skills_db ALTER COLUMN DatumZeit SET DATA TYPE TIMESTAMP USING strptime(DatumZeit, '%b %-j, %Y %H:%M:%S');")

# %%
df = cursor.sql("SELECT * FROM postgres_db.public.goalies;").df()

# %%
df.head()
# Out:
#             Name    vorname mannschaft geburtsdatum          Player Name  \
# 0        Kanobel      Yanis       FE12   2013-11-26        Yanis Kanobel
# 1       Kleeberg      Junis       FE12   2013-06-07       Junis Kleeberg
# 2           Polo     Laurin       FE12   2013-05-14          Laurin Polo
# 3  Röthlisberger      Roman       FE12   2013-07-29  Roman Röthlisberger
# 4            Ung  Enea Levi       FE12   2013-05-21        Enea Levi Ung
#
#   initialen
# 0        YK
# 1        JK
# 2        LP
# 3        RR
# 4        EU
